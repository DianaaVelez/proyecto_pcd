# %% [markdown]
# Borrador

# %%
import pandas as pd 
import numpy as np
import re
import matplotlib as mpl 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sentiments = pd.read_csv('sentimentdataset.csv')

# %%
sentiments.shape
# Out:
# (732, 15)

# %%
sentiments.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Text', 'Sentiment', 'Timestamp', 'User',
#        'Platform', 'Hashtags', 'Retweets', 'Likes', 'Country', 'Year', 'Month',
#        'Day', 'Hour'],
#       dtype='object')

# %%
sentiments['Sentiment'] = sentiments['Sentiment'].str.strip() #limpiar
sentpositivos = sentiments.loc[sentiments['Sentiment'] == 'Positive']
sentpositivos
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               0           0
# 2               2           2
# 3               3           3
# 5               5           5
# 6               6           6
# 7               7           7
# 10             10          10
# 12             12          12
# 13             13          13
# 15             15          15
# 16             16          16
# 17             17          17
# 20             20          20
# 21             21          21
# 22             22          22
# 23             23          23
# 24             24          24
# 25             25          25
# 26             27          28
# 27             28          29
# 28             29          30
# 29             30          31
# 30             31          32
# 31             32          33
# 32             33          34
# 33             34          35
# 34             35          36
# 35             36          37
# 36             37          38
# 37             38          39
# 38             39          40
# 39             40          41
# 40             41          42
# 41             42          43
# 42             43          44
# 43             44          45
# 44             45          46
# 45             46          47
# 46             47          48
# 47             48          49
# 48             49          50
# 49             50          51
# 50             51          52
# 51             52          53
# 647           648         652
#
#                                                   Text Sentiment  \
# 0     Enjoying a beautiful day at the park!        ...  Positive
# 2     Just finished an amazing workout! 💪          ...  Positive
# 3     Excited about the upcoming weekend getaway!  ...  Positive
# 5     Feeling grateful for the little things in lif...  Positive
# 6     Rainy days call for cozy blankets and hot coc...  Positive
# 7     The new movie release is a must-watch!       ...  Positive
# 10    Just published a new blog post. Check it out!...  Positive
# 12    Exploring the city's hidden gems.            ...  Positive
# 13    New year, new fitness goals! 💪               ...  Positive
# 15    Reflecting on the past and looking ahead.    ...  Positive
# 16    Just adopted a cute furry friend! 🐾          ...  Positive
# 17    Late-night gaming session with friends.      ...  Positive
# 20    Sipping coffee and enjoying a good book.     ...  Positive
# 21    Exploring the world of virtual reality.      ...  Positive
# 22    Productive day ticking off my to-do list.    ...  Positive
# 23    Just finished a challenging workout routine. ...  Positive
# 24    Celebrating a milestone at work! 🎉           ...  Positive
# 25    Sunday brunch with friends.                  ...  Positive
# 26    Learning a new language for personal growth. ...  Positive
# 27    Quiet evening with a good book.              ...  Positive
# 28    Reflecting on the importance of mental health...  Positive
# 29    New painting in progress! 🎨                  ...  Positive
# 30    Weekend road trip to explore scenic views.   ...  Positive
# 31    Enjoying a cup of tea and watching the sunset...  Positive
# 32    Coding a new project with enthusiasm.        ...  Positive
# 33    Feeling inspired after attending a workshop. ...  Positive
# 34    Winter sports day at the local park.         ...  Positive
# 35    Quality time with family this weekend.       ...  Positive
# 36    Attending a live music concert tonight.      ...  Positive
# 37    Practicing mindfulness with meditation.      ...  Positive
# 38    Trying out a new dessert recipe.             ...  Positive
# 39    Excited about the upcoming gaming tournament....  Positive
# 40    Planning a garden makeover for spring.       ...  Positive
# 41    Celebrating a friend's birthday tonight! 🎂   ...  Positive
# 42    Feeling accomplished after a productive day. ...  Positive
# 43    A cozy evening with a good movie.            ...  Positive
# 44    Exploring local art galleries this weekend.  ...  Positive
# 45    New book release from my favorite author!    ...  Positive
# 46    Attending a virtual reality meetup.          ...  Positive
# 47    Reflecting on the beauty of nature.          ...  Positive
# 48    Cooking a special dinner for loved ones.     ...  Positive
# 49    Feeling optimistic about the week ahead.     ...  Positive
# 50    Starting a new fitness challenge tomorrow! 💪 ...  Positive
# 51    Sunday bike ride through scenic trails.      ...  Positive
# 647  Convinced the teacher to have class outdoors. ...  Positive
#
#                Timestamp                      User     Platform  \
# 0    2023-01-15 12:30:00             User123          Twitter
# 2    2023-01-15 15:45:00             FitnessFan      Instagram
# 3    2023-01-15 18:20:00             AdventureX       Facebook
# 5    2023-01-16 09:10:00             GratitudeNow     Twitter
# 6    2023-01-16 14:45:00             RainyDays        Facebook
# 7    2023-01-16 19:30:00             MovieBuff       Instagram
# 10   2023-01-17 15:15:00             BloggerX        Instagram
# 12   2023-01-18 14:50:00             UrbanExplorer    Facebook
# 13   2023-01-18 18:00:00             FitJourney      Instagram
# 15   2023-01-19 13:20:00             Reflections      Facebook
# 16   2023-01-19 17:10:00             PetAdopter      Instagram
# 17   2023-01-20 00:05:00             GamerX           Twitter
# 20   2023-01-21 08:40:00             Bookworm         Twitter
# 21   2023-01-21 13:20:00             VRExplorer       Facebook
# 22   2023-01-21 16:45:00           ProductivityPro   Instagram
# 23   2023-01-22 09:15:00            FitnessWarrior    Twitter
# 24   2023-01-22 14:30:00           CareerMilestone    Facebook
# 25   2023-01-22 12:00:00             BrunchBuddy     Instagram
# 26   2023-01-23 16:20:00           LanguageLearner    Facebook
# 27   2023-01-23 19:45:00             BookLover       Instagram
# 28   2023-01-24 11:30:00       MentalHealthMatters    Twitter
# 29   2023-01-24 15:00:00            ArtistInAction    Facebook
# 30   2023-01-24 17:30:00             RoadTripper     Instagram
# 31   2023-01-25 18:00:00             SunsetWatcher    Twitter
# 32   2023-01-25 13:15:00            CodeEnthusiast    Facebook
# 33   2023-01-26 09:45:00          WorkshopAttendee   Instagram
# 34   2023-01-26 14:20:00            WinterSports      Twitter
# 35   2023-01-26 17:40:00             FamilyTime       Facebook
# 36   2023-01-27 20:00:00             MusicLover      Instagram
# 37   2023-01-27 12:30:00            MindfulMoments    Twitter
# 38   2023-01-27 16:10:00           DessertExplorer    Facebook
# 39   2023-01-28 09:00:00          GamingEnthusiast   Instagram
# 40   2023-01-28 14:45:00            GardenPlanner     Twitter
# 41   2023-01-28 19:30:00             BirthdayBash     Facebook
# 42   2023-01-29 17:00:00           ProductivityWin   Instagram
# 43   2023-01-29 20:20:00             MovieNight       Twitter
# 44   2023-01-30 11:30:00             ArtExplorer      Facebook
# 45   2023-01-30 15:45:00             BookwormX       Instagram
# 46   2023-01-30 18:30:00             VRMeetup         Twitter
# 47   2023-01-31 10:45:00             NatureLover      Facebook
# 48   2023-01-31 19:00:00             ChefAtHome      Instagram
# 49   2023-01-31 16:20:00         OptimisticMindset    Twitter
# 50   2023-02-01 08:00:00          FitnessChallenge    Facebook
# 51   2023-02-01 13:30:00            BikeExplorer     Instagram
# 647  2023-08-06 14:00:00   OutdoorClassHighSchool     Facebook
#
#                                        Hashtags  Retweets  Likes  \
# 0     #Nature #Park                                  15.0   30.0
# 2     #Fitness #Workout                              20.0   40.0
# 3     #Travel #Adventure                              8.0   15.0
# 5       #Gratitude #PositiveVibes                    25.0   50.0
# 6     #RainyDays #Cozy                               10.0   20.0
# 7      #MovieNight #MustWatch                        15.0   30.0
# 10     #Blogging #NewPost                            22.0   45.0
# 12     #CityExplore #HiddenGems                      12.0   25.0
# 13     #NewYear #FitnessGoals                        28.0   55.0
# 15     #Reflection #Future                           20.0   40.0
# 16     #PetAdoption #FurryFriend                     15.0   30.0
# 17     #Gaming #LateNight                            18.0   35.0
# 20     #Reading #CoffeeTime                          22.0   45.0
# 21     #VR #VirtualReality                           15.0   30.0
# 22       #Productivity #WorkFromHome                 30.0   60.0
# 23     #Fitness #ChallengeAccepted                   20.0   40.0
# 24     #Career #Milestone                            12.0   25.0
# 25      #Brunch #Friends                             15.0   30.0
# 26     #LanguageLearning #PersonalGrowth             25.0   50.0
# 27     #Reading #QuietTime                           15.0   30.0
# 28     #MentalHealth #SelfCare                       22.0   45.0
# 29        #Art #PaintingInProgress                   12.0   25.0
# 30     #RoadTrip #ScenicViews                        18.0   35.0
# 31      #TeaTime #Sunset                             15.0   30.0
# 32       #Coding #Enthusiasm                         30.0   60.0
# 33     #Inspiration #Workshop                        25.0   50.0
# 34      #WinterSports #Fun                           15.0   30.0
# 35     #FamilyTime #Weekend                          22.0   45.0
# 36       #Music #ConcertNight                        18.0   35.0
# 37      #Mindfulness #Meditation                     15.0   30.0
# 38      #Dessert #Cooking                            12.0   25.0
# 39     #Gaming #Tournament                           30.0   60.0
# 40      #Gardening #Spring                           25.0   50.0
# 41     #Birthday #Celebration                        15.0   30.0
# 42        #Accomplished #Success                     22.0   45.0
# 43     #CozyNight #MovieTime                         18.0   35.0
# 44     #Art #GalleryExplore                          15.0   30.0
# 45      #BookRelease #FavoriteAuthor                 12.0   25.0
# 46     #VRMeetup #VirtualReality                     28.0   55.0
# 47     #Nature #Reflection                           15.0   30.0
# 48      #Cooking #SpecialDinner                      20.0   40.0
# 49      #Optimism #NewWeek                           15.0   30.0
# 50      #FitnessChallenge #NewBeginnings             22.0   45.0
# 51      #BikeRide #ScenicTrails                      18.0   35.0
# 647      #OutdoorClassroom #HighSchoolExplorer       28.0   55.0
#
#           Country  Year  Month  Day  Hour
# 0       USA        2023      1   15    12
# 2     USA          2023      1   15    15
# 3       UK         2023      1   15    18
# 5       India      2023      1   16     9
# 6       Canada     2023      1   16    14
# 7         USA      2023      1   16    19
# 10            USA  2023      1   17    15
# 12      UK         2023      1   18    14
# 13    USA          2023      1   18    18
# 15      USA        2023      1   19    13
# 16     Canada      2023      1   19    17
# 17      UK         2023      1   20     0
# 20      India      2023      1   21     8
# 21            USA  2023      1   21    13
# 22           USA   2023      1   21    16
# 23      UK         2023      1   22     9
# 24       Canada    2023      1   22    14
# 25            UK   2023      1   22    12
# 26     India       2023      1   23    16
# 27     Australia   2023      1   23    19
# 28      USA        2023      1   24    11
# 29        Canada   2023      1   24    15
# 30     UK          2023      1   24    17
# 31      India      2023      1   25    18
# 32           USA   2023      1   25    13
# 33            USA  2023      1   26     9
# 34      Canada     2023      1   26    14
# 35     UK          2023      1   26    17
# 36           USA   2023      1   27    20
# 37      India      2023      1   27    12
# 38        Canada   2023      1   27    16
# 39            USA  2023      1   28     9
# 40      USA        2023      1   28    14
# 41            UK   2023      1   28    19
# 42         India   2023      1   29    17
# 43      Canada     2023      1   29    20
# 44      USA        2023      1   30    11
# 45          UK     2023      1   30    15
# 46      India      2023      1   30    18
# 47     Australia   2023      1   31    10
# 48     USA         2023      1   31    19
# 49      Canada     2023      1   31    16
# 50    UK           2023      2    1     8
# 51       USA       2023      2    1    13
# 647           USA  2023      8    6    14

# %%
sentnegativos = sentiments.loc[sentiments['Sentiment'] == 'Negative']
sentnegativos
# Out:
#     Unnamed: 0.1  Unnamed: 0  \
# 1              1           1
# 8              8           8
# 11            11          11
# 19            19          19
#
#                                                  Text Sentiment  \
# 1    Traffic was terrible this morning.           ...  Negative
# 8    Political discussions heating up on the timel...  Negative
# 11   Feeling a bit under the weather today.       ...  Negative
# 19   Winter blues got me feeling low.             ...  Negative
#
#               Timestamp            User     Platform  \
# 1   2023-01-15 08:45:00   CommuterX        Twitter
# 8   2023-01-17 08:00:00   DebateTalk       Twitter
# 11  2023-01-18 10:30:00   WellnessCheck    Twitter
# 19  2023-01-20 15:15:00   WinterBlues     Instagram
#
#                                       Hashtags  Retweets  Likes      Country  \
# 1    #Traffic #Morning                               5.0   10.0    Canada
# 8     #Politics #Debate                             30.0   60.0    USA
# 11    #SickDay #Health                               7.0   15.0    Canada
# 19    #WinterBlues #Mood                             8.0   15.0   USA
#
#     Year  Month  Day  Hour
# 1   2023      1   15     8
# 8   2023      1   17     8
# 11  2023      1   18    10
# 19  2023      1   20    15

# %%
sentneutrales = sentiments.loc[sentiments['Sentiment'] == 'Neutral']
sentneutrales
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 4               4           4
# 9               9           9
# 14             14          14
# 18             18          18
# 704           705         709
# 705           706         710
# 706           707         711
# 707           708         712
# 708           709         713
# 709           710         714
# 710           711         715
# 711           712         716
# 712           713         717
# 713           714         718
# 714           715         719
# 715           716         720
# 716           717         721
# 717           718         722
#
#                                                   Text Sentiment  \
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# 9     Missing summer vibes and beach days.         ...   Neutral
# 14    Technology is changing the way we live.      ...   Neutral
# 18    Attending a virtual conference on AI.        ...   Neutral
# 704  Trying out a new study technique for upcoming ...   Neutral
# 705  Organizing a community cleanup event for a cle...   Neutral
# 706  Sharing favorite book recommendations with cla...   Neutral
# 707  Experimenting with a new recipe for a school b...   Neutral
# 708  Collaborating on a school project with peers. ...   Neutral
# 709  Attending a school club meeting to explore new...   Neutral
# 710  Exploring a new part-time job opportunity for ...   Neutral
# 711  Attending a school assembly to stay informed a...   Neutral
# 712  Exploring a new hobby of photography during fr...   Neutral
# 713  Participating in a science fair to showcase a ...   Neutral
# 714  Attending a workshop on time management to enh...   Neutral
# 715  Volunteering at a local charity event to give ...   Neutral
# 716  Collaborating on a group project to promote te...   Neutral
# 717  Participating in a debate club to enhance crit...   Neutral
#
#                Timestamp                                     User  \
# 4    2023-01-15 19:55:00                            ChefCook
# 9    2023-01-17 12:20:00                            BeachLover
# 14   2023-01-19 09:45:00                           TechEnthusiast
# 18   2023-01-20 11:30:00                           TechConference
# 704  2023-10-02 16:45:00      StudyTechniqueExperimentHighSchool
# 705  2023-10-03 12:30:00              CommunityCleanupHighSchool
# 706  2023-10-04 18:20:00           BookRecommendationsHighSchool
# 707  2023-10-05 14:15:00      BakeSaleRecipeExperimentHighSchool
# 708  2023-10-06 17:30:00    SchoolProjectCollaborationHighSchool
# 709  2023-10-07 20:45:00    ExtracurricularExplorationHighSchool
# 710  2023-10-08 15:15:00        PartTimeJobExplorationHighSchool
# 711  2023-10-09 22:00:00   SchoolAssemblyParticipationHighSchool
# 712  2023-10-10 14:15:00              PhotographyHobbyHighSchool
# 713  2023-10-11 16:45:00      ScienceFairParticipationHighSchool
# 714  2023-10-12 18:20:00        TimeManagementWorkshopHighSchool
# 715  2023-10-13 12:30:00         CharityEventVolunteerHighSchool
# 716  2023-10-14 17:30:00     GroupProjectCollaborationHighSchool
# 717  2023-10-15 20:45:00       DebateClubParticipationHighSchool
#
#         Platform                                      Hashtags  Retweets  \
# 4     Instagram      #Cooking #Food                                 12.0
# 9      Facebook       #Summer #BeachDays                            18.0
# 14     Twitter        #Tech #Innovation                             15.0
# 18     Facebook       #AI #TechConference                           25.0
# 704   Instagram             #StudyStrategies #HighSchoolExams       23.0
# 705     Twitter    #EnvironmentalEfforts #HighSchoolCommunity       26.0
# 706    Facebook                    #BookClub #HighSchoolReads       19.0
# 707   Instagram            #BakingAdventures #HighSchoolBakes       21.0
# 708     Twitter                 #Teamwork #HighSchoolProjects       18.0
# 709   Instagram             #SchoolClubs #HighSchoolInterests       22.0
# 710    Facebook            #CareerDevelopment #HighSchoolJobs       24.0
# 711     Twitter         #SchoolEvents #HighSchoolConnectivity       20.0
# 712   Instagram        #PhotographyJourney #HighSchoolHobbies       25.0
# 713    Facebook               #ScienceFair #HighSchoolScience       19.0
# 714     Twitter            #EfficiencyGoals #HighSchoolSkills       23.0
# 715   Instagram        #CommunityService #HighSchoolVolunteer       20.0
# 716    Facebook               #TeamSpirit #HighSchoolProjects       18.0
# 717     Twitter            #DebateSkills #HighSchoolIntellect       22.0
#
#      Likes      Country  Year  Month  Day  Hour
# 4     25.0   Australia   2023      1   15    19
# 9     35.0   Australia   2023      1   17    12
# 14    30.0    India      2023      1   19     9
# 18    50.0          USA  2023      1   20    11
# 704   42.0          USA  2023     10    2    16
# 705   50.0       Canada  2023     10    3    12
# 706   38.0           UK  2023     10    4    18
# 707   43.0          USA  2023     10    5    14
# 708   36.0       Canada  2023     10    6    17
# 709   45.0           UK  2023     10    7    20
# 710   48.0          USA  2023     10    8    15
# 711   40.0       Canada  2023     10    9    22
# 712   49.0           UK  2023     10   10    14
# 713   37.0          USA  2023     10   11    16
# 714   44.0       Canada  2023     10   12    18
# 715   39.0           UK  2023     10   13    12
# 716   35.0          USA  2023     10   14    17
# 717   43.0       Canada  2023     10   15    20

# %%
sentpositivos.shape
# Out:
# (45, 15)

# %%
sentnegativos.shape
# Out:
# (4, 15)

# %%
sentneutrales.shape
# Out:
# (18, 15)

# %%
# Filas únicas
filas_unicas = sentiments.drop_duplicates()

# Cuenta cuántas filas únicas hay
num_filas_unicas = len(filas_unicas)

print(f"El número de filas únicas es: {num_filas_unicas}")
# Out:
# El número de filas únicas es: 732

# %%
# Cambia 'nombre_columna' por el nombre de la columna que quieres analizar
valores_unicos = sentiments['Sentiment'].nunique()

print(f"El número de valores únicos en la columna es: {valores_unicos}")
# Out:
# El número de valores únicos en la columna es: 191

# %%
sentiments2['Sentiment'] = sentiments['Sentiment'].str.replace('Anger' 'Sadness' 'Fear''Disgust''Affectetion' 'Awe' 'Disappointmented' 'Disappointment' 'Bitter' 'Bitterness' 'Shame' 'Anxiety' 'Envy' 'Regret' 'Despair' 'Grief' 'Loneliness' 'Jealousy' 'Resentment' 'Frustation' 'Boredom' 'Indifference' 'Melancholy' 'Nostalgia' 'Fearful' 'Apprehensive' 'Overwhelmed' 'Debastated' 'Frustated' 'Envious' 'Dismissive' 'insolation' 'Darkness' 'Desperation' 'Whimsy' 'Betrayal' 'Heartbreak' 'Loss' 'Suffering' 'EmotionalStorm' 'LostLove' 'Exhaustion' 'Sorrow' 'Bad' 'Hate' 'Sad' 'Ruins' 'Solitude' ' Embarrassed' 'Obstacle' 'Pressure' 'Miscaculation' 'Mischievous', 'Negative')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 sentiments2['Sentiment'] = sentiments['Sentiment'].str.replace('Anger' 'Sadness' 'Fear''Disgust''Affectetion' 'Awe' 'Disappointmented' 'Disappointment' 'Bitter' 'Bitterness' 'Shame' 'Anxiety' 'Envy' 'Regret' 'Despair' 'Grief' 'Loneliness' 'Jealousy' 'Resentment' 'Frustation' 'Boredom' 'Indifference' 'Melancholy' 'Nostalgia' 'Fearful' 'Apprehensive' 'Overwhelmed' 'Debastated' 'Frustated' 'Envious' 'Dismissive' 'insolation' 'Darkness' 'Desperation' 'Whimsy' 'Betrayal' 'Heartbreak' 'Loss' 'Suffering' 'EmotionalStorm' 'LostLove' 'Exhaustion' 'Sorrow' 'Bad' 'Hate' 'Sad' 'Ruins' 'Solitude' ' Embarrassed' 'Obstacle' 'Pressure' 'Miscaculation' 'Mischievous', 'Negative')
#
# NameError: name 'sentiments2' is not defined

# %%
sentiments2['Sentiment'] = sentiments2['Sentiment'].str.strip() #limpiar
sentnegativos2 = sentiments.loc[sentiments['Sentiment'] == 'Negative']
sentnegativos2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 sentiments2['Sentiment'] = sentiments2['Sentiment'].str.strip() #limpiar
#       2 sentnegativos2 = sentiments.loc[sentiments['Sentiment'] == 'Negative']
#       3 sentnegativos2
#
# NameError: name 'sentiments2' is not defined

# %%
sentnegativos2.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 sentnegativos2.shape
#
# NameError: name 'sentnegativos2' is not defined

# %%
# Supongamos que ya tienes un DataFrame llamado sentiments con la columna 'Sentiment'

# Definir las palabras que deben reemplazarse por "Negative"
palabras_a_reemplazar = [
    'Anger', 'Sadness', 'Fear', 'Disgust', 'Affection', 'Awe', 'Disappointment',
    'Bitter', 'Bitterness', 'Shame', 'Anxiety', 'Envy', 'Regret', 'Despair',
    'Grief', 'Loneliness', 'Jealousy', 'Resentment', 'Frustration', 'Boredom',
    'Indifference', 'Melancholy', 'Nostalgia', 'Fearful', 'Apprehensive',
    'Overwhelmed', 'Devastated', 'Frustrated', 'Envious', 'Dismissive',
    'Isolation', 'Darkness', 'Desperation', 'Whimsy', 'Betrayal', 'Heartbreak',
    'Loss', 'Suffering', 'EmotionalStorm', 'LostLove', 'Exhaustion', 'Sorrow',
    'Bad', 'Hate', 'Sad', 'Ruins', 'Solitude', 'Embarrassed', 'Obstacle',
    'Pressure', 'Miscalculation', 'Mischievous', ' Intimidation'
]

expresion = re.compile('|'.join(palabras_a_reemplazar), flags=re.IGNORECASE)

# Reemplazar todas las palabras en 'Sentiment' por 'Negative'
sentiments['Sentiment'] = sentiments['Sentiment'].str.replace(expresion, 'Negative', regex=True)

# Limpiar espacios en blanco
sentiments['Sentiment'] = sentiments['Sentiment'].str.strip()

# Filtrar las filas donde 'Sentiment' sea igual a 'Negative'
sentnegativos2 = sentiments.loc[sentiments['Sentiment'] == 'Negative']
sentnegativos2
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 1               1           1
# 8               8           8
# 11             11          11
# 19             19          19
# 52             53          55
# ..            ...         ...
# 699           700         704
# 700           701         705
# 701           702         706
# 702           703         707
# 703           704         708
#
#                                                   Text Sentiment  \
# 1     Traffic was terrible this morning.           ...  Negative
# 8     Political discussions heating up on the timel...  Negative
# 11    Feeling a bit under the weather today.       ...  Negative
# 19    Winter blues got me feeling low.             ...  Negative
# 52    Can't believe the injustice happening in our ...  Negative
# ..                                                 ...       ...
# 699  Having a bad hair day and feeling self-conscio...  Negative
# 700  Feeling a sense of despair after a major proje...  Negative
# 701  Experiencing hate comments for expressing pers...  Negative
# 702  Having a string of bad luck with constant tech...  Negative
# 703  Missing out on a long-anticipated event due to...  Negative
#
#                Timestamp                               User     Platform  \
# 1    2023-01-15 08:45:00                      CommuterX        Twitter
# 8    2023-01-17 08:00:00                      DebateTalk       Twitter
# 11   2023-01-18 10:30:00                      WellnessCheck    Twitter
# 19   2023-01-20 15:15:00                      WinterBlues     Instagram
# 52   2023-02-11 09:30:00                   SocialJustice       Twitter
# ..                   ...                                ...          ...
# 699  2023-09-27 17:30:00         BadHairDayBluesHighSchool    Instagram
# 700  2023-09-28 22:00:00   ProjectFailureDespairHighSchool     Facebook
# 701  2023-09-29 15:45:00            OpinionsHateHighSchool      Twitter
# 702  2023-09-30 18:20:00     TechMalfunctionWoesHighSchool    Instagram
# 703  2023-10-01 14:15:00        MissedEventBluesHighSchool     Facebook
#
#                                            Hashtags  Retweets  Likes  \
# 1         #Traffic #Morning                               5.0   10.0
# 8          #Politics #Debate                             30.0   60.0
# 11         #SickDay #Health                               7.0   15.0
# 19         #WinterBlues #Mood                             8.0   15.0
# 52    #Injustice #Angry                                  20.0   40.0
# ..                                              ...       ...    ...
# 699              #BadHairDay #HighSchoolConfidence       18.0   36.0
# 700         #ProjectStruggles #HighSchoolHardships       21.0   41.0
# 701           #OnlineOpinions #HighSchoolCriticism       24.0   48.0
# 702                    #TechIssues #HighSchoolTech       22.0   43.0
# 703               #MissedMoments #HighSchoolRegret       20.0   39.0
#
#           Country  Year  Month  Day  Hour
# 1       Canada     2023      1   15     8
# 8       USA        2023      1   17     8
# 11      Canada     2023      1   18    10
# 19     USA         2023      1   20    15
# 52    Canada       2023      2   11     9
# ..            ...   ...    ...  ...   ...
# 699        Canada  2023      9   27    17
# 700            UK  2023      9   28    22
# 701           USA  2023      9   29    15
# 702        Canada  2023      9   30    18
# 703            UK  2023     10    1    14
#
# [190 rows x 15 columns]

# %%
sentnegativos2.shape
# Out:
# (190, 15)

# %%
# Para positive
palabras_a_reemplazar = [
    'Hapiness', 'Joy', 'Love', 'Enjoyment', 'Kind',  'Excitement' ,  'Calmness',  'Adoration',
    'Acceptance', 'Anticipation', 'Pride', 'Elation', 'Fulfillment', 'Enthusiasm', 
    'Compassion', 'Empowerment', 'Hope', 'Gratitude', 'Serenity', 'Happy',
    'Zest', 'Contentment', 'Hopeful', 'Playful',  'Free-spirited', 'Proud', 'Empathetic', 
    'Surprise', 'Tenderness', 'Acceptance', 'Arousal', 'Compassionate','Inspired', 'Curiosity',
    'Thrill', 'Overjoyed', 'Optimism', 'Surprise', 'Elation', 'Mindfulness', 'DreamChaser', 
    'Elegance', 'Whimsy', 'Harmony', 'Rejuvenation', 'Inspiration', 'Adventure', 
    'FestiveJoy', 'InnerJourney', 'Freedom', 'Reflection', 'ArtisticBurst', 
    'Radiance', 'Wonder', 'CulinaryOdyssey', ' Coziness', 'Resilience', 
    'Immersion', 'Success', 'Reflection', 'Enchantment', 'Exploration', 'Amazement', 'Romance', 
    'Excitement', 'Tranquility', 'Energy', 'Celebration', 'Charm', 'Creativity',
    'Colorful', 'Iconic', 'Contemplation', 'Determination', 'Heartwarming', 'Reflection',  
    'Renewed Effort',  'Sympathy', 'Solace', 'Mesmerizing', "Nature's Beauty", 
    'Celestial Wonder',  'Creative Inspiration',  'Runway Creativity', "Ocean's Freedom" ,
    'Surprise', 'Contentment', 'Gratitude'
]

expresion = re.compile('|'.join(palabras_a_reemplazar), flags=re.IGNORECASE)

sentiments['Sentiment'] = sentiments['Sentiment'].str.replace(expresion, 'Positive', regex=True)

# Limpiar espacios en blanco
sentiments['Sentiment'] = sentiments['Sentiment'].str.strip()

# Filtrar las filas donde 'Sentiment' sea igual a 'Negative'
sentpositivos3 = sentiments.loc[sentiments['Sentiment'] == 'Positive']
sentpositivos2
# Out:
#   Cell In[23], line 9
#     'Elegance', 'Whimsy', 'Harmony', 'Rejuvenation', 'Inspiration', 'Adventure',
#                          ^
# SyntaxError: invalid non-printable character U+00A0

# %%
import re
import pandas as pd

# Corregir y limpiar palabras
palabras_a_reemplazar = [
    'Happiness', 'Joy', 'Love', 'Enjoyment', 'Kind', 'Excitement', 'Calmness', 'Adoration',
    'Acceptance', 'Anticipation', 'Pride', 'Elation', 'Fulfillment', 'Enthusiasm', 
    'Compassion', 'Empowerment', 'Hope', 'Gratitude', 'Serenity', 'Happy',
    'Zest', 'Contentment', 'Hopeful', 'Playful', 'Free-spirited', 'Proud', 'Empathetic', 
    'Surprise', 'Tenderness', 'Arousal', 'Compassionate', 'Inspired', 'Curiosity',
    'Thrill', 'Overjoyed', 'Optimism', 'Mindfulness', 'DreamChaser', 
    'Elegance', 'Whimsy', 'Harmony', 'Rejuvenation', 'Inspiration', 'Adventure', 
    'FestiveJoy', 'InnerJourney', 'Freedom', 'Reflection', 'Adrenaline', 'ArtisticBurst', 
    'Radiance', 'Wonder', 'CulinaryOdyssey', 'Coziness', 'Resilience', 
    'Immersion', 'Success', 'Enchantment', 'Exploration', 'Amazement', 'Romance',
    'Tranquility', 'Energy', 'Celebration', 'Charm', 'Creativity',
    'Colorful', 'Iconic', 'Contemplation', 'Determination', 'Heartwarming',  
    'Renewed Effort', 'Sympathy', 'Solace', 'Mesmerizing', "Nature's Beauty", 
    'Celestial Wonder', 'Creative Inspiration', 'Runway Creativity', "Ocean's Freedom"
]

# Crear expresión regular
expresion = re.compile('|'.join(map(str.strip, palabras_a_reemplazar)), flags=re.IGNORECASE)

# Reemplazar palabras por 'Positive'
sentiments['Sentiment'] = sentiments['Sentiment'].str.replace(expresion, 'Positive', regex=True)

# Limpiar espacios en blanco
sentiments['Sentiment'] = sentiments['Sentiment'].str.strip()

# Filtrar las filas donde 'Sentiment' sea igual a 'Positive'
sentpositivos2 = sentiments.loc[sentiments['Sentiment'] == 'Positive']
sentpositivos2
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               0           0
# 2               2           2
# 3               3           3
# 5               5           5
# 6               6           6
# ..            ...         ...
# 727           728         732
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text Sentiment  \
# 0     Enjoying a beautiful day at the park!        ...  Positive
# 2     Just finished an amazing workout! 💪          ...  Positive
# 3     Excited about the upcoming weekend getaway!  ...  Positive
# 5     Feeling grateful for the little things in lif...  Positive
# 6     Rainy days call for cozy blankets and hot coc...  Positive
# ..                                                 ...       ...
# 727  Collaborating on a science project that receiv...  Positive
# 728  Attending a surprise birthday party organized ...  Positive
# 729  Successfully fundraising for a school charity ...  Positive
# 730  Participating in a multicultural festival, cel...  Positive
# 731  Organizing a virtual talent show during challe...  Positive
#
#                Timestamp                                   User     Platform  \
# 0    2023-01-15 12:30:00                          User123          Twitter
# 2    2023-01-15 15:45:00                          FitnessFan      Instagram
# 3    2023-01-15 18:20:00                          AdventureX       Facebook
# 5    2023-01-16 09:10:00                          GratitudeNow     Twitter
# 6    2023-01-16 14:45:00                          RainyDays        Facebook
# ..                   ...                                    ...          ...
# 727  2017-08-18 18:20:00       ScienceProjectSuccessHighSchool     Facebook
# 728  2018-06-22 14:15:00            BirthdayPartyJoyHighSchool    Instagram
# 729  2019-04-05 17:30:00   CharityFundraisingTriumphHighSchool      Twitter
# 730  2020-02-29 20:45:00    MulticulturalFestivalJoyHighSchool     Facebook
# 731  2020-11-15 15:15:00    VirtualTalentShowSuccessHighSchool    Instagram
#
#                                           Hashtags  Retweets  Likes  \
# 0        #Nature #Park                                  15.0   30.0
# 2        #Fitness #Workout                              20.0   40.0
# 3        #Travel #Adventure                              8.0   15.0
# 5          #Gratitude #PositiveVibes                    25.0   50.0
# 6        #RainyDays #Cozy                               10.0   20.0
# ..                                             ...       ...    ...
# 727         #ScienceFairWinner #HighSchoolScience       20.0   39.0
# 728    #SurpriseCelebration #HighSchoolFriendship       25.0   48.0
# 729      #CommunityGiving #HighSchoolPhilanthropy       22.0   42.0
# 730         #CulturalCelebration #HighSchoolUnity       21.0   43.0
# 731   #VirtualEntertainment #HighSchoolPositivity       24.0   47.0
#
#           Country  Year  Month  Day  Hour
# 0       USA        2023      1   15    12
# 2     USA          2023      1   15    15
# 3       UK         2023      1   15    18
# 5       India      2023      1   16     9
# 6       Canada     2023      1   16    14
# ..            ...   ...    ...  ...   ...
# 727            UK  2017      8   18    18
# 728           USA  2018      6   22    14
# 729        Canada  2019      4    5    17
# 730            UK  2020      2   29    20
# 731           USA  2020     11   15    15
#
# [395 rows x 15 columns]

# %%
sentpositivos2.shape
# Out:
# (395, 15)

# %%
palabras_diferentes != 'Positive', 'Negative'
sentiments2['Sentiment'] = sentiments2['Sentiment'].str.replace(palabras_diferentes, 'Neutral', regex=True)

# Limpiar espacios en blanco
sentiments2['Sentiment'] = sentiments2['Sentiment'].str.strip()

# Filtrar las filas donde 'Sentiment' sea igual a 'Positive'
sentneutrales2 = sentiments2.loc[sentiments2['Sentiment'] == 'Positive']
sentneutrales2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 palabras_diferentes != 'Positive', 'Negative'
#       2 sentiments2['Sentiment'] = sentiments2['Sentiment'].str.replace(palabras_diferentes, 'Neutral', regex=True)
#       4 # Limpiar espacios en blanco
#
# NameError: name 'palabras_diferentes' is not defined

# %%
# Supongamos que ya tienes un DataFrame llamado sentiments con la columna 'Sentiment'

# Palabras que deben ser reemplazadas por 'Negative'
# Palabras corregidas y limpiadas
palabras_negativas = [
    'Anger', 'Sadness', 'Fear', 'Disgust', 'Affection', 'Awe', 'Disappointment',
    'Bitter', 'Bitterness', 'Shame', 'Anxiety', 'Envy', 'Regret', 'Despair',
    'Grief', 'Loneliness', 'Jealousy', 'Resentment', 'Frustration', 'Boredom',
    'Indifference', 'Melancholy', 'Nostalgia', 'Fearful', 'Apprehensive',
    'Overwhelmed', 'Devastated', 'Frustrated', 'Envious', 'Dismissive',
    'Isolation', 'Darkness', 'Desperation', 'Whimsy', 'Betrayal', 'Heartbreak',
    'Loss', 'Suffering', 'EmotionalStorm', 'LostLove', 'Exhaustion', 'Sorrow',
    'Bad', 'Hate', 'Sad', 'Ruins', 'Solitude', 'Embarrassed', 'Obstacle',
    'Pressure', 'Miscalculation', 'Mischievous', 'Intimidation', 'Breakthrough',
    'Desolation', 'Despair', 'Devastated', 'Disappointed', 'Disgust', 
    'Dismissive', 'Embarrassed', 'Envious', 'Grief', 'Heartache', 'Heartbreak', 
    'Helplessness', 'Indifference', 'Loss', 'Overwhelmed', 'Shame', 'Sorrow', 
    'Solitude', 'Suffering'
]

expresion_negativa = re.compile('|'.join(map(str.strip, palabras_negativas)), flags=re.IGNORECASE)
sentiments['Sentiment'] = sentiments['Sentiment'].str.replace(expresion_negativa, 'Negative', regex=True)
sentiments['Sentiment'] = sentiments['Sentiment'].str.strip()
sentnegativos2 = sentiments.loc[sentiments['Sentiment'] == 'Negative']
sentnegativos2
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 1               1           1
# 8               8           8
# 11             11          11
# 19             19          19
# 52             53          55
# ..            ...         ...
# 699           700         704
# 700           701         705
# 701           702         706
# 702           703         707
# 703           704         708
#
#                                                   Text Sentiment  \
# 1     Traffic was terrible this morning.           ...  Negative
# 8     Political discussions heating up on the timel...  Negative
# 11    Feeling a bit under the weather today.       ...  Negative
# 19    Winter blues got me feeling low.             ...  Negative
# 52    Can't believe the injustice happening in our ...  Negative
# ..                                                 ...       ...
# 699  Having a bad hair day and feeling self-conscio...  Negative
# 700  Feeling a sense of despair after a major proje...  Negative
# 701  Experiencing hate comments for expressing pers...  Negative
# 702  Having a string of bad luck with constant tech...  Negative
# 703  Missing out on a long-anticipated event due to...  Negative
#
#                Timestamp                               User     Platform  \
# 1    2023-01-15 08:45:00                      CommuterX        Twitter
# 8    2023-01-17 08:00:00                      DebateTalk       Twitter
# 11   2023-01-18 10:30:00                      WellnessCheck    Twitter
# 19   2023-01-20 15:15:00                      WinterBlues     Instagram
# 52   2023-02-11 09:30:00                   SocialJustice       Twitter
# ..                   ...                                ...          ...
# 699  2023-09-27 17:30:00         BadHairDayBluesHighSchool    Instagram
# 700  2023-09-28 22:00:00   ProjectFailureDespairHighSchool     Facebook
# 701  2023-09-29 15:45:00            OpinionsHateHighSchool      Twitter
# 702  2023-09-30 18:20:00     TechMalfunctionWoesHighSchool    Instagram
# 703  2023-10-01 14:15:00        MissedEventBluesHighSchool     Facebook
#
#                                            Hashtags  Retweets  Likes  \
# 1         #Traffic #Morning                               5.0   10.0
# 8          #Politics #Debate                             30.0   60.0
# 11         #SickDay #Health                               7.0   15.0
# 19         #WinterBlues #Mood                             8.0   15.0
# 52    #Injustice #Angry                                  20.0   40.0
# ..                                              ...       ...    ...
# 699              #BadHairDay #HighSchoolConfidence       18.0   36.0
# 700         #ProjectStruggles #HighSchoolHardships       21.0   41.0
# 701           #OnlineOpinions #HighSchoolCriticism       24.0   48.0
# 702                    #TechIssues #HighSchoolTech       22.0   43.0
# 703               #MissedMoments #HighSchoolRegret       20.0   39.0
#
#           Country  Year  Month  Day  Hour
# 1       Canada     2023      1   15     8
# 8       USA        2023      1   17     8
# 11      Canada     2023      1   18    10
# 19     USA         2023      1   20    15
# 52    Canada       2023      2   11     9
# ..            ...   ...    ...  ...   ...
# 699        Canada  2023      9   27    17
# 700            UK  2023      9   28    22
# 701           USA  2023      9   29    15
# 702        Canada  2023      9   30    18
# 703            UK  2023     10    1    14
#
# [202 rows x 15 columns]

# %%
import re
import pandas as pd

# Eliminar duplicados y normalizar la lista
palabras_positivas = [
    'Happiness', 'Joy', 'Love', 'Enjoyment', 'Kind', 'Excitement', 'Calmness', 'Adoration',
    'Acceptance', 'Anticipation', 'Pride', 'Elation', 'Fulfillment', 'Enthusiasm', 
    'Compassion', 'Empowerment', 'Hope', 'Gratitude', 'Serenity', 'Happy',
    'Zest', 'Contentment', 'Hopeful', 'Playful', 'Free-spirited', 'Proud', 'Empathetic', 
    'Surprise', 'Tenderness', 'Arousal', 'Compassionate', 'Inspired', 'Curiosity',
    'Thrill', 'Overjoyed', 'Optimism', 'Mindfulness', 'DreamChaser', 
    'Elegance', 'Whimsy', 'Harmony', 'Rejuvenation', 'Inspiration', 'Adventure', 
    'FestiveJoy', 'InnerJourney', 'Freedom', 'Reflection', 'Adrenaline', 'ArtisticBurst', 
    'Radiance', 'Wonder', 'CulinaryOdyssey', 'Coziness', 'Resilience', 
    'Immersion', 'Success', 'Enchantment', 'Exploration', 'Amazement', 'Romance',
    'Tranquility', 'Energy', 'Celebration', 'Charm', 'Creativity',
    'Colorful', 'Iconic', 'Contemplation', 'Determination', 'Heartwarming',  
    'Renewed Effort', 'Sympathy', 'Solace', 'Mesmerizing', "Nature's Beauty", 
    'Celestial Wonder', 'Creative Inspiration', 'Runway Creativity', "Ocean's Freedom",
    'Accomplishment', 'Admiration', 'Affection', 'Amusement', 'Appreciation', 'Blessed', 
    'Connection', 'Culinary Adventure', 'Dazzle', 'Ecstasy', 'Emotion', 
    'Grateful', 'Grandeur', 'Imagination', 'Journey', 'JoyfulReunion', 'Kindness', 
    'PlayfulJoy', 'Relief', 'Satisfaction', 'Thrilling Journey', 'Touched', 'Triumph', 
    'Vibrancy', 'Wonderment'
]
palabras_positivas = list(dict.fromkeys([palabra.strip() for palabra in palabras_positivas]))

# Crear la expresión regular
expresion_positiva = re.compile('|'.join(map(re.escape, palabras_positivas)), flags=re.IGNORECASE)

# Reemplazar palabras por 'Positive'
sentiments['Sentiment'] = sentiments['Sentiment'].str.replace(expresion_positiva, 'Positive', regex=True)

# Limpiar espacios
sentiments['Sentiment'] = sentiments['Sentiment'].str.strip()

# Filtrar los sentimientos positivos
sentpositivos2 = sentiments.loc[sentiments['Sentiment'] == 'Positive']
sentpositivos2
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               0           0
# 2               2           2
# 3               3           3
# 5               5           5
# 6               6           6
# ..            ...         ...
# 727           728         732
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text Sentiment  \
# 0     Enjoying a beautiful day at the park!        ...  Positive
# 2     Just finished an amazing workout! 💪          ...  Positive
# 3     Excited about the upcoming weekend getaway!  ...  Positive
# 5     Feeling grateful for the little things in lif...  Positive
# 6     Rainy days call for cozy blankets and hot coc...  Positive
# ..                                                 ...       ...
# 727  Collaborating on a science project that receiv...  Positive
# 728  Attending a surprise birthday party organized ...  Positive
# 729  Successfully fundraising for a school charity ...  Positive
# 730  Participating in a multicultural festival, cel...  Positive
# 731  Organizing a virtual talent show during challe...  Positive
#
#                Timestamp                                   User     Platform  \
# 0    2023-01-15 12:30:00                          User123          Twitter
# 2    2023-01-15 15:45:00                          FitnessFan      Instagram
# 3    2023-01-15 18:20:00                          AdventureX       Facebook
# 5    2023-01-16 09:10:00                          GratitudeNow     Twitter
# 6    2023-01-16 14:45:00                          RainyDays        Facebook
# ..                   ...                                    ...          ...
# 727  2017-08-18 18:20:00       ScienceProjectSuccessHighSchool     Facebook
# 728  2018-06-22 14:15:00            BirthdayPartyJoyHighSchool    Instagram
# 729  2019-04-05 17:30:00   CharityFundraisingTriumphHighSchool      Twitter
# 730  2020-02-29 20:45:00    MulticulturalFestivalJoyHighSchool     Facebook
# 731  2020-11-15 15:15:00    VirtualTalentShowSuccessHighSchool    Instagram
#
#                                           Hashtags  Retweets  Likes  \
# 0        #Nature #Park                                  15.0   30.0
# 2        #Fitness #Workout                              20.0   40.0
# 3        #Travel #Adventure                              8.0   15.0
# 5          #Gratitude #PositiveVibes                    25.0   50.0
# 6        #RainyDays #Cozy                               10.0   20.0
# ..                                             ...       ...    ...
# 727         #ScienceFairWinner #HighSchoolScience       20.0   39.0
# 728    #SurpriseCelebration #HighSchoolFriendship       25.0   48.0
# 729      #CommunityGiving #HighSchoolPhilanthropy       22.0   42.0
# 730         #CulturalCelebration #HighSchoolUnity       21.0   43.0
# 731   #VirtualEntertainment #HighSchoolPositivity       24.0   47.0
#
#           Country  Year  Month  Day  Hour
# 0       USA        2023      1   15    12
# 2     USA          2023      1   15    15
# 3       UK         2023      1   15    18
# 5       India      2023      1   16     9
# 6       Canada     2023      1   16    14
# ..            ...   ...    ...  ...   ...
# 727            UK  2017      8   18    18
# 728           USA  2018      6   22    14
# 729        Canada  2019      4    5    17
# 730            UK  2020      2   29    20
# 731           USA  2020     11   15    15
#
# [426 rows x 15 columns]

# %%
# Asignar 'Neutral' a los que no son 'Positive' ni 'Negative'
sentiments['Sentiment'] = sentiments['Sentiment'].apply(lambda x: 'Neutral' if x not in ['Positive', 'Negative'] else x)

# Limpiar espacios en blanco
sentiments['Sentiment'] = sentiments['Sentiment'].str.strip()

# Filtrar los resultados
sentneutrales2 = sentiments.loc[sentiments['Sentiment'] == 'Neutral']
sentneutrales2
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 4               4           4
# 9               9           9
# 14             14          14
# 18             18          18
# 71             72          74
# ..            ...         ...
# 713           714         718
# 714           715         719
# 715           716         720
# 716           717         721
# 717           718         722
#
#                                                   Text Sentiment  \
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# 9     Missing summer vibes and beach days.         ...   Neutral
# 14    Technology is changing the way we live.      ...   Neutral
# 18    Attending a virtual conference on AI.        ...   Neutral
# 71    Confusion clouds my mind as I navigate throug...   Neutral
# ..                                                 ...       ...
# 713  Participating in a science fair to showcase a ...   Neutral
# 714  Attending a workshop on time management to enh...   Neutral
# 715  Volunteering at a local charity event to give ...   Neutral
# 716  Collaborating on a group project to promote te...   Neutral
# 717  Participating in a debate club to enhance crit...   Neutral
#
#                Timestamp                                   User     Platform  \
# 4    2023-01-15 19:55:00                          ChefCook        Instagram
# 9    2023-01-17 12:20:00                          BeachLover       Facebook
# 14   2023-01-19 09:45:00                         TechEnthusiast    Twitter
# 18   2023-01-20 11:30:00                         TechConference    Facebook
# 71   2023-02-18 14:20:00                       ConfusedMind       Instagram
# ..                   ...                                    ...          ...
# 713  2023-10-11 16:45:00    ScienceFairParticipationHighSchool     Facebook
# 714  2023-10-12 18:20:00      TimeManagementWorkshopHighSchool      Twitter
# 715  2023-10-13 12:30:00       CharityEventVolunteerHighSchool    Instagram
# 716  2023-10-14 17:30:00   GroupProjectCollaborationHighSchool     Facebook
# 717  2023-10-15 20:45:00     DebateClubParticipationHighSchool      Twitter
#
#                                          Hashtags  Retweets  Likes  \
# 4       #Cooking #Food                                 12.0   25.0
# 9        #Summer #BeachDays                            18.0   35.0
# 14       #Tech #Innovation                             15.0   30.0
# 18       #AI #TechConference                           25.0   50.0
# 71    #Confusion #DecisionMaking                       25.0   50.0
# ..                                            ...       ...    ...
# 713              #ScienceFair #HighSchoolScience       19.0   37.0
# 714           #EfficiencyGoals #HighSchoolSkills       23.0   44.0
# 715       #CommunityService #HighSchoolVolunteer       20.0   39.0
# 716              #TeamSpirit #HighSchoolProjects       18.0   35.0
# 717           #DebateSkills #HighSchoolIntellect       22.0   43.0
#
#          Country  Year  Month  Day  Hour
# 4     Australia   2023      1   15    19
# 9     Australia   2023      1   17    12
# 14     India      2023      1   19     9
# 18           USA  2023      1   20    11
# 71         UK     2023      2   18    14
# ..           ...   ...    ...  ...   ...
# 713          USA  2023     10   11    16
# 714       Canada  2023     10   12    18
# 715           UK  2023     10   13    12
# 716          USA  2023     10   14    17
# 717       Canada  2023     10   15    20
#
# [104 rows x 15 columns]

# %%
sentnegativos2 .shape
# Out:
# (202, 15)

# %%
sentpositivos2.shape
# Out:
# (426, 15)

# %%
sentneutrales2.shape
# Out:
# (104, 15)

# %%
sentiments
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               0           0
# 1               1           1
# 2               2           2
# 3               3           3
# 4               4           4
# ..            ...         ...
# 727           728         732
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text Sentiment  \
# 0     Enjoying a beautiful day at the park!        ...  Positive
# 1     Traffic was terrible this morning.           ...  Negative
# 2     Just finished an amazing workout! 💪          ...  Positive
# 3     Excited about the upcoming weekend getaway!  ...  Positive
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# ..                                                 ...       ...
# 727  Collaborating on a science project that receiv...  Positive
# 728  Attending a surprise birthday party organized ...  Positive
# 729  Successfully fundraising for a school charity ...  Positive
# 730  Participating in a multicultural festival, cel...  Positive
# 731  Organizing a virtual talent show during challe...  Positive
#
#                Timestamp                                   User     Platform  \
# 0    2023-01-15 12:30:00                          User123          Twitter
# 1    2023-01-15 08:45:00                          CommuterX        Twitter
# 2    2023-01-15 15:45:00                          FitnessFan      Instagram
# 3    2023-01-15 18:20:00                          AdventureX       Facebook
# 4    2023-01-15 19:55:00                          ChefCook        Instagram
# ..                   ...                                    ...          ...
# 727  2017-08-18 18:20:00       ScienceProjectSuccessHighSchool     Facebook
# 728  2018-06-22 14:15:00            BirthdayPartyJoyHighSchool    Instagram
# 729  2019-04-05 17:30:00   CharityFundraisingTriumphHighSchool      Twitter
# 730  2020-02-29 20:45:00    MulticulturalFestivalJoyHighSchool     Facebook
# 731  2020-11-15 15:15:00    VirtualTalentShowSuccessHighSchool    Instagram
#
#                                           Hashtags  Retweets  Likes  \
# 0        #Nature #Park                                  15.0   30.0
# 1        #Traffic #Morning                               5.0   10.0
# 2        #Fitness #Workout                              20.0   40.0
# 3        #Travel #Adventure                              8.0   15.0
# 4        #Cooking #Food                                 12.0   25.0
# ..                                             ...       ...    ...
# 727         #ScienceFairWinner #HighSchoolScience       20.0   39.0
# 728    #SurpriseCelebration #HighSchoolFriendship       25.0   48.0
# 729      #CommunityGiving #HighSchoolPhilanthropy       22.0   42.0
# 730         #CulturalCelebration #HighSchoolUnity       21.0   43.0
# 731   #VirtualEntertainment #HighSchoolPositivity       24.0   47.0
#
#           Country  Year  Month  Day  Hour
# 0       USA        2023      1   15    12
# 1       Canada     2023      1   15     8
# 2     USA          2023      1   15    15
# 3       UK         2023      1   15    18
# 4      Australia   2023      1   15    19
# ..            ...   ...    ...  ...   ...
# 727            UK  2017      8   18    18
# 728           USA  2018      6   22    14
# 729        Canada  2019      4    5    17
# 730            UK  2020      2   29    20
# 731           USA  2020     11   15    15
#
# [732 rows x 15 columns]

# %%
# Cambia 'nombre_columna' por el nombre de la columna que quieres analizar
valores_unicos = sentiments['Sentiment'].nunique()

print(f"El número de valores únicos en la columna es: {valores_unicos}")
# Out:
# El número de valores únicos en la columna es: 3

# %%
# Contar ocurrencias de cada categoría
conteo = sentiments['Sentiment'].value_counts()
conteo
# Out:
# Sentiment
# Positive    426
# Negative    202
# Neutral     104
# Name: count, dtype: int64

# %%
# Calcular porcentaje
porcentajes = (conteo / len(sentiments)) * 100
porcentajes
# Out:
# Sentiment
# Positive    58.196721
# Negative    27.595628
# Neutral     14.207650
# Name: count, dtype: float64

# %%
# %matplotlib inline
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
labels = ['Positive', 'Negative', 'Neutral']
sizes = [58.19, 27.59, 14.20]  # Porcentajes de cada categoría

# Crear la gráfica de pastel
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=180)
plt.title('Distribución de Sentimientos', fontsize=16)
plt.show()
